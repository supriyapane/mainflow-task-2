# %%
#importing ipl dataset
import pandas as pd
ds=pd.read_csv("/home/rgukt/Documents/e2sem2/data science lab/archive(1).zip")
print(ds)
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
#retriving first 5 columns of dataset
ds.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
#retrivind last 7 columns in ipl dataset
ds.tail(7)
# Out:
#     match_id         date                             venue      team1  \
# 67        68  May 20,2022         Brabourne Stadium, Mumbai    Chennai
# 68        69  May 21,2022          Wankhede Stadium, Mumbai      Delhi
# 69        70  May 22,2022          Wankhede Stadium, Mumbai  Hyderabad
# 70        71  May 24,2022             Eden Gardens, Kolkata    Gujarat
# 71        72  May 25,2022             Eden Gardens, Kolkata   Banglore
# 72        73  May 27,2022  Narendra Modi Stadium, Ahmedabad   Banglore
# 73        74  May 29,2022  Narendra Modi Stadium, Ahmedabad    Gujarat
#
#         team2    stage toss_winner toss_decision  first_ings_score  \
# 67  Rajasthan    Group     Chennai           Bat               150
# 68     Mumbai    Group      Mumbai         Field               159
# 69     Punjab    Group   Hyderabad           Bat               157
# 70  Rajasthan  Playoff     Gujarat         Field               188
# ...

# %%
ds.describe()
# Out:
#         match_id  first_ings_score  first_ings_wkts  second_ings_score  \
# count  74.000000         74.000000        74.000000          74.000000
# mean   37.500000        171.121622         6.135135         158.540541
# std    21.505813         29.048355         2.222699          29.299207
# min     1.000000         68.000000         0.000000          72.000000
# 25%    19.250000        154.250000         5.000000         142.750000
# 50%    37.500000        169.500000         6.000000         160.000000
# 75%    55.750000        192.750000         8.000000         176.000000
# max    74.000000        222.000000        10.000000         211.000000
#
#        second_ings_wkts     margin   highscore
# count         74.000000  74.000000   74.000000
# mean           6.175676  16.972973   71.716216
# std            2.639832  19.651047   20.705052
# min            1.000000   2.000000   28.000000
# 25%            4.000000   5.250000   57.000000
# ...

# %%
ds=ds.drop_duplicates()
ds
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
#creating a new dataframe
import pandas as pd
import numpy as np
dict={"first score":[100,90,np.nan,76],
      "second score":[70,67,65,np.nan],
       "third score":[np.nan,43,48,86],
        "fourth score":[10,40,78,96]}
df=pd.DataFrame(dict)
print(df)
# Out:
#    first score  second score  third score  fourth score
# 0        100.0          70.0          NaN            10
# 1         90.0          67.0         43.0            40
# 2          NaN          65.0         48.0            78
# 3         76.0           NaN         86.0            96

# %%
df.isnull()  #gives boolean output
# Out:
#    first score  second score  third score  fourth score
# 0        False         False         True         False
# 1        False         False        False         False
# 2         True         False        False         False
# 3        False          True        False         False

# %%
df.isnull().sum()
# Out:
# first score     1
# second score    1
# third score     1
# fourth score    0
# dtype: int64

# %%
df.notnull()
# Out:
#    first score  second score  third score  fourth score
# 0         True          True        False          True
# 1         True          True         True          True
# 2        False          True         True          True
# 3         True         False         True          True

# %%
df.isnull().sum().sum()
# Out:
# 3

# %%
d2=df.fillna(value=0)
d2
# Out:
#    first score  second score  third score  fourth score
# 0        100.0          70.0          0.0            10
# 1         90.0          67.0         43.0            40
# 2          0.0          65.0         48.0            78
# 3         76.0           0.0         86.0            96

# %%
import numpy as np
from scipy import stats
d2.columns
# Out:
# Index(['first score', 'second score', 'third score', 'fourth score'], dtype='object')

# %%
#every row information using iteration
for i,j in df.iterrows():
    print(i,j)
    print()
# Out:
# 0 first score     100.0
# second score     70.0
# third score       NaN
# forth score      10.0
# Name: 0, dtype: float64
#
# 1 first score     90.0
# second score    67.0
# third score     43.0
# forth score     40.0
# Name: 1, dtype: float64
#
# 2 first score      NaN
# second score    65.0
# third score     48.0
# forth score     78.0
# Name: 2, dtype: float64
#
# 3 first score     76.0
# second score     NaN
# third score     86.0
# forth score     96.0
# Name: 3, dtype: float64

# %%
q1=d2.quantile(0.25)
q3=d2.quantile(0.75)
iqr=q3-q1
print(iqr)
# Out:
# first score     35.50
# second score    19.00
# third score     25.25
# fourth score    50.00
# dtype: float64

# %%
d2=d2[~((d2<(q1-1.5*iqr))|(d2>(q3+1.5*iqr))).any(axis=1)]
d2
# Out:
#    first score  second score  third score  fourth score
# 0        100.0          70.0          0.0            10
# 1         90.0          67.0         43.0            40
